# %%
#to start with like a ritual
print("Hello World")
# Out:
# Hello World

# %%
#variables are lika a container for keeping values and for further uses
x = 30
y = 40
#we can now use x and y whenever we required
#Lets say we want to know the sum
total = x + y
print(total)
# Out:
# 70
